# %% [markdown]
# # Evil Bastard Features

# %%
import pandas as pd
import numpy as np

from config import *
from features.feature_utils import *

# %%
experiment = "EVIL_BASTARD"
participant_ids = pd.read_parquet(
        f"{PREPROCESSED_DIR}/{experiment}_samples.pq", 
        columns=["participant_id"]
    )

participant_ids = participant_ids["participant_id"].unique()

# %%
def get_samples_df(participant_id):
    df_samples = pd.read_parquet(
        f"{PREPROCESSED_DIR}/{experiment}_samples.pq",
        filters=[('participant_id', '=', participant_id)]
        )
    return df_samples
    
def get_events_df(participant_id):
    df_events = pd.read_parquet(
        f"{PREPROCESSED_DIR}/{experiment}_events.pq",
        filters=[('participant_id', '=', participant_id)]
        )
    
    return df_events

# %%
participant_id = 147

df_sample = get_samples_df(participant_id)
df_event = get_events_df(participant_id)

# %%
def combine_samples_events(df_sample: pd.DataFrame, df_event: pd.DataFrame) -> pd.DataFrame:
    """Combine sample data and event data to get fixpoints.
    
    Args:
        df_sample (pd.DataFrame): Dataframe with preprocessed sample data
        df_event (pd.DataFrame): Dataframe with preprocessed event data

    Returns:
        pd.DataFrame: Dataframe with fixpoints added to the sample data.
    """
    
    # Extract fixpoints
    df_fixpoints = df_event[df_event["event"]=="FIXPOINT"].loc[:,["participant_id", "trial_id", "time", "event", "colour", "stimulus_x", "stimulus_y"]]

    # Insert fixpoints in sample data
    df_sample = df_sample.copy()
    df_fixpoints = df_fixpoints.copy()

    # Make sure both DataFrames are sorted by time
    df_sample = df_sample.sort_values(["time", "trial_id", "participant_id"])
    df_fixpoints = df_fixpoints.sort_values(["time", "trial_id", "participant_id"])

    # Rename 'colour' column to 'fixpoint' so it's ready to merge
    df_fixpoints = df_fixpoints.rename(columns={"colour": "fixpoint"})

    # Perform a backward-looking join: for each row in sample_df, find the most recent fixpoint time
    df_sample = pd.merge_asof(
        df_sample,
        df_fixpoints,
        on="time",
        by=["participant_id", "trial_id"],
        direction="nearest",
        tolerance=10
    )

    df_sample["fixpoint"] = df_sample["fixpoint"].map({RED:"red", GREEN:"green", BLUE:"blue", WHITE:"white"})
    
    return df_sample

# %%
def evil_bastard_get_distance_to_stimulus_features(df: pd.DataFrame) -> pd.DataFrame:
    features = (df
        .assign(
            distance_to_fixpoint_left = lambda x: (x["x_left"]-x["stimulus_x"])**2+(x["y_left"]-x["stimulus_y"])**2,
            distance_to_fixpoint_right = lambda x: (x["x_right"]-x["stimulus_x"])**2+(x["y_right"]-x["stimulus_y"])**2
        )
        .assign(
            distance_to_fixpoint = lambda x: 
                np.where(
                    ~x["distance_to_fixpoint_left"].isna() & ~x["distance_to_fixpoint_right"].isna(),
                    (x["distance_to_fixpoint_left"]+x["distance_to_fixpoint_right"])/2,
                
                    np.where(
                        ~x["distance_to_fixpoint_left"].isna(),
                        x["distance_to_fixpoint_left"],
                        x["distance_to_fixpoint_right"]
                    )
                )
        )
        .groupby(["experiment", "participant_id"])
        .agg({
            'distance_to_fixpoint': ["mean", "min", "max", "median", "std"],
        })
        .reset_index()
        .pipe(rename_columns)
    )
    
    return features

# %%
def get_distance_between_fixations(df: pd.DataFrame) -> pd.DataFrame:
    """Finds acceleration features for anti saccade experiment

    Args:
        df (pd.DataFrame): Dataframe with preprocessed events

    Returns:
        pd.DataFrame: Dataframe with columns ['experiment','participant_id', X_FEATURES]
        where X_FEATURES is a collection of features found by the following cartesian product:
    """

    df = (df.query("event == 'EFIX'")
    .join((df
        .query("event == 'EFIX'")
        .groupby(["experiment", "participant_id", "trial_id", "eye"])[['x','y']].shift(1)
        .rename(columns={"x": "x_lagged", 
            "y": "y_lagged"})))
    .assign(
        x_fixation_dist = lambda x: x["x"] - x["x_lagged"],
        y_fixation_dist = lambda x: x["y"] - x["y_lagged"])
    .assign(
        fixation_distance = lambda x: np.sqrt( np.power(x["x_fixation_dist"],2) + np.power(x["y_fixation_dist"],2))
    )
    .groupby(["experiment", "participant_id"])
    .agg({'fixation_distance': [np.mean, np.std],
    })
    .reset_index()
    .pipe(rename_columns)
    )
    return df

# %%
def get_evil_bastard_features() -> pd.DataFrame:
    """Runs all evil features extractions

    Returns:
        pd.DataFrame: Dataframe with columns ["experiment", "participant_id", X_FEATURES], where X_FEATURES is a collection of features
    """

    logging.info("Extracting anti saccade features")
    
    experiment = "EVIL_BASTARD"
    
    # Read participant and trial id to identify unique participants
    df_index = pd.read_parquet(
        f"{PREPROCESSED_DIR}/{experiment}_events.pq", 
        columns=["participant_id"]
    )
    participant_groups = df_index["participant_id"].unique()
    
    df_features_all_participants = []
    for participant_id in tqdm(participant_groups, total=len(participant_groups)):
        logging.info(f"Processing participant {participant_id}")

        filters = [('participant_id', '=', participant_id)]
        df_event = pd.read_parquet(PREPROCESSED_DIR / f"{experiment}_events.pq", filters=filters)
        df_sample = (pd.read_parquet(PREPROCESSED_DIR / f'{experiment}_samples.pq', filters=filters)
        .sort_values(["experiment", "participant_id", "trial_id","time"])
        )
        df_combined = combine_samples_events(df_sample, df_event)
        
        logging.info("Starting event feature extraction")
        event_feature_functions = [get_pre_calculated_metrics_feature, get_distance_between_fixations]
        df_event_features_list = [f(df=df_event) for f in event_feature_functions]

        logging.info("Starting sample feature extraction")
        sample_feature_functions = [get_acceleration_feature, get_disconjugacy_feature]
        df_sample_features_list = [f(df=df_sample) for f in sample_feature_functions]
        
        logging.info("Starting combined feature extraction")
        combined_feature_functions = [evil_bastard_get_distance_to_stimulus_features]
        df_combined_features_list = [f(df=df_combined) for f in combined_feature_functions]
    
        df_features_par_list = df_event_features_list + df_sample_features_list + df_combined_features_list
    
        df_features_par = reduce(lambda x, y: pd.merge(x, y, on = ["experiment", "participant_id"]), df_features_par_list)

        df_features_all_participants.append(df_features_par)
    
    df_features = pd.concat(df_features_all_participants, ignore_index=True)
    
    logging.info("Finished extracting anti saccade features")
    
    return df_features

# %%
features=get_evil_bastard_features()
# Out:
# 2025-04-21 17:16:01,778 - INFO - 2255764734.get_evil_bastard_features:8 - Extracting anti saccade features
#   0%|          | 0/160 [00:00<?, ?it/s]2025-04-21 17:16:02,069 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 106
# 2025-04-21 17:16:05,228 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:05,347 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:05,348 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:05,897 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:07,816 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   1%|          | 1/160 [00:06<16:06,  6.08s/it]2025-04-21 17:16:08,157 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 111
# 2025-04-21 17:16:09,825 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:09,899 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:09,900 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:10,685 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:11,964 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   1%|▏         | 2/160 [00:10<13:57,  5.30s/it]2025-04-21 17:16:12,903 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 133
# 2025-04-21 17:16:13,746 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:14,036 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:14,040 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:14,979 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:15,678 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   2%|▏         | 3/160 [00:13<11:11,  4.28s/it]2025-04-21 17:16:15,966 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 134
# 2025-04-21 17:16:16,859 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:16,896 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:16,897 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:17,242 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:18,793 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   2%|▎         | 4/160 [00:17<09:58,  3.84s/it]2025-04-21 17:16:19,126 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 135
# 2025-04-21 17:16:20,631 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:20,698 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:20,699 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:21,864 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:22,722 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   3%|▎         | 5/160 [00:20<09:55,  3.84s/it]2025-04-21 17:16:22,978 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 137
# 2025-04-21 17:16:23,660 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:23,699 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:23,700 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:23,992 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:24,740 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   4%|▍         | 6/160 [00:22<08:14,  3.21s/it]2025-04-21 17:16:24,972 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 138
# 2025-04-21 17:16:25,717 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:25,756 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:25,757 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:26,049 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:27,036 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   4%|▍         | 7/160 [00:25<07:38,  2.99s/it]2025-04-21 17:16:27,512 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 142
# 2025-04-21 17:16:29,146 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:29,235 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:29,236 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:29,679 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:30,627 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   5%|▌         | 8/160 [00:28<07:53,  3.12s/it]2025-04-21 17:16:30,889 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 143
# 2025-04-21 17:16:31,777 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:31,835 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:31,836 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:32,124 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:32,823 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   6%|▌         | 9/160 [00:31<07:23,  2.93s/it]2025-04-21 17:16:33,428 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 144
# 2025-04-21 17:16:34,661 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:35,119 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:35,126 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:36,062 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:37,815 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   6%|▋         | 10/160 [00:36<08:43,  3.49s/it]2025-04-21 17:16:38,153 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 146
# 2025-04-21 17:16:39,807 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:39,870 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:39,871 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:40,199 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:41,765 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   7%|▋         | 11/160 [00:39<08:56,  3.60s/it]2025-04-21 17:16:41,999 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 147
# 2025-04-21 17:16:42,645 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:42,931 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:42,934 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:43,798 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:43,960 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   8%|▊         | 12/160 [00:42<07:49,  3.17s/it]2025-04-21 17:16:44,188 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 149
# 2025-04-21 17:16:45,807 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:45,874 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:45,875 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:46,323 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:47,996 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   8%|▊         | 13/160 [00:46<08:58,  3.66s/it]2025-04-21 17:16:48,985 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 150
# 2025-04-21 17:16:50,227 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:50,678 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:50,683 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:51,186 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:53,707 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   9%|▉         | 14/160 [00:51<09:51,  4.05s/it]2025-04-21 17:16:53,944 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 151
# 2025-04-21 17:16:54,713 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:54,780 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:54,781 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:55,942 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:16:57,010 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#   9%|▉         | 15/160 [00:55<09:31,  3.94s/it]2025-04-21 17:16:57,623 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 152
# 2025-04-21 17:16:58,919 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:16:59,285 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:16:59,286 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:16:59,640 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:17:01,154 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#  10%|█         | 16/160 [00:59<09:22,  3.90s/it]2025-04-21 17:17:01,439 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 153
# 2025-04-21 17:17:03,609 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:17:04,033 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:17:04,038 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:17:04,733 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
# 2025-04-21 17:17:06,446 - INFO - 2255764734.get_evil_bastard_features:38 - Starting combined feature extraction
#  11%|█         | 17/160 [01:04<10:20,  4.34s/it]2025-04-21 17:17:06,786 - INFO - 2255764734.get_evil_bastard_features:21 - Processing participant 156
# 2025-04-21 17:17:07,574 - INFO - 2255764734.get_evil_bastard_features:30 - Starting event feature extraction
# 2025-04-21 17:17:07,620 - INFO - 2255764734.get_evil_bastard_features:34 - Starting sample feature extraction
# 2025-04-21 17:17:07,621 - INFO - feature_utils.get_acceleration_feature:52 - Extracting acceleration
# 2025-04-21 17:17:08,390 - INFO - feature_utils.get_disconjugacy_feature:78 - Extracting disconjugacy
