# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
anti_saccade_events = pd.read_parquet("../data/processed/ANTI_SACCADE.pq")
anti_saccade_events
# Out:
#           experiment participant_id  trial_id       time     event  \
# 0       ANTI_SACCADE            103       0.0  2354775.0   TRIALID
# 1       ANTI_SACCADE            103       0.0  2354807.0     START
# 2       ANTI_SACCADE            103       0.0  2354842.0  FIXPOINT
# 3       ANTI_SACCADE            103       0.0  2354987.0      SFIX
# 4       ANTI_SACCADE            103       0.0  2355008.0      SFIX
# ...              ...            ...       ...        ...       ...
# 127091  ANTI_SACCADE             96       5.0        NaN      EFIX
# 127092  ANTI_SACCADE             96       5.0        NaN     ESACC
# 127093  ANTI_SACCADE             96       5.0        NaN     ESACC
# 127094  ANTI_SACCADE             96       5.0        NaN      EFIX
# 127095  ANTI_SACCADE             96       5.0        NaN      EFIX
#
#              colour  stimulus_x  stimulus_y   eye  start_time  ...  \
# 0              None         NaN         NaN  None         NaN  ...
# ...
